# %%
import pandas as pd
import numpy as np
from PyALE import ale
import joblib
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt

# %%
pip install catboost
# Out:
# Collecting catboost
#   Using cached catboost-1.1.1-cp39-none-macosx_10_6_universal2.whl (22.0 MB)
# Requirement already satisfied: numpy>=1.16.0 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.21.5)
# Requirement already satisfied: six in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24.0 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.4.4)
# Requirement already satisfied: scipy in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.9.1)
# Requirement already satisfied: plotly in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from catboost) (5.9.0)
# Collecting graphviz
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: matplotlib in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from catboost) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->catboost) (2022.1)
# Requirement already satisfied: cycler>=0.10 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages (from plotly->catboost) (8.0.1)
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.1.1 graphviz-0.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
cat = joblib.load("models/CatBoostClassifier_mode_allcat.pkl")
df = pd.read_csv("in-vehicle-coupon-recommendation.csv")
df_ohe = pd.read_csv("data/ohe_mode_allcat.csv")

ohe_col = ['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
       'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
       'education', 'occupation', 'income', 'car', 'Bar', 'CoffeeHouse',
       'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50',
       'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
       'direction_same', 'direction_opp']
# Out:
# /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator Pipeline from version 1.2.0 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/andrewyaholkovsky/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator GridSearchCV from version 1.2.0 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
df_ohe.drop(columns=['Unnamed: 0'],inplace=True)

# %%
def fillnull(col):
    col.fillna(col.value_counts().index[0], inplace=True)
    return col

df = df.apply(lambda col: fillnull(col))

# %%
df_ohe.columns
# Out:
# Index(['destination_Home', 'destination_No Urgent Place', 'destination_Work',
#        'passanger_Alone', 'passanger_Friend(s)', 'passanger_Kid(s)',
#        'passanger_Partner', 'weather_Rainy', 'weather_Snowy', 'weather_Sunny',
#        ...
#        'toCoupon_GEQ5min_1', 'toCoupon_GEQ15min_0', 'toCoupon_GEQ15min_1',
#        'toCoupon_GEQ25min_0', 'toCoupon_GEQ25min_1', 'direction_same_0',
#        'direction_same_1', 'direction_opp_0', 'direction_opp_1', 'Y'],
#       dtype='object', length=128)

# %%
# df transformation
df['temperature'] = df['temperature'].astype(object)
for i in df.columns[:-1]:
    df[i] = f'{i}_' + df[i].astype(str)

# %%
df.head()
# Out:
#                    destination            passanger        weather  \
# 0  destination_No Urgent Place      passanger_Alone  weather_Sunny
# 1  destination_No Urgent Place  passanger_Friend(s)  weather_Sunny
# 2  destination_No Urgent Place  passanger_Friend(s)  weather_Sunny
# 3  destination_No Urgent Place  passanger_Friend(s)  weather_Sunny
# 4  destination_No Urgent Place  passanger_Friend(s)  weather_Sunny
#
#       temperature       time                        coupon     expiration  \
# 0  temperature_55   time_2PM        coupon_Restaurant(<20)  expiration_1d
# 1  temperature_80  time_10AM           coupon_Coffee House  expiration_2h
# 2  temperature_80  time_10AM  coupon_Carry out & Take away  expiration_2h
# 3  temperature_80   time_2PM           coupon_Coffee House  expiration_2h
# 4  temperature_80   time_2PM           coupon_Coffee House  expiration_1d
#
#           gender     age                    maritalStatus  ...  \
# 0  gender_Female  age_21  maritalStatus_Unmarried partner  ...
# 1  gender_Female  age_21  maritalStatus_Unmarried partner  ...
# 2  gender_Female  age_21  maritalStatus_Unmarried partner  ...
# 3  gender_Female  age_21  maritalStatus_Unmarried partner  ...
# 4  gender_Female  age_21  maritalStatus_Unmarried partner  ...
#
#          CoffeeHouse      CarryAway      RestaurantLessThan20  \
# 0  CoffeeHouse_never  CarryAway_1~3  RestaurantLessThan20_4~8
# 1  CoffeeHouse_never  CarryAway_1~3  RestaurantLessThan20_4~8
# 2  CoffeeHouse_never  CarryAway_1~3  RestaurantLessThan20_4~8
# 3  CoffeeHouse_never  CarryAway_1~3  RestaurantLessThan20_4~8
# 4  CoffeeHouse_never  CarryAway_1~3  RestaurantLessThan20_4~8
#
#        Restaurant20To50    toCoupon_GEQ5min    toCoupon_GEQ15min  \
# 0  Restaurant20To50_1~3  toCoupon_GEQ5min_1  toCoupon_GEQ15min_0
# 1  Restaurant20To50_1~3  toCoupon_GEQ5min_1  toCoupon_GEQ15min_0
# 2  Restaurant20To50_1~3  toCoupon_GEQ5min_1  toCoupon_GEQ15min_1
# 3  Restaurant20To50_1~3  toCoupon_GEQ5min_1  toCoupon_GEQ15min_1
# 4  Restaurant20To50_1~3  toCoupon_GEQ5min_1  toCoupon_GEQ15min_1
#
#      toCoupon_GEQ25min    direction_same    direction_opp  Y
# 0  toCoupon_GEQ25min_0  direction_same_0  direction_opp_1  1
# 1  toCoupon_GEQ25min_0  direction_same_0  direction_opp_1  0
# 2  toCoupon_GEQ25min_0  direction_same_0  direction_opp_1  1
# 3  toCoupon_GEQ25min_0  direction_same_0  direction_opp_1  0
# 4  toCoupon_GEQ25min_0  direction_same_0  direction_opp_1  0
#
# [5 rows x 26 columns]

# %%
from pyale import hyeni_pyale

# %%
ale_col = 'toCoupon_GEQ15min'
ohe = OneHotEncoder()
coded_feature = pd.DataFrame(ohe.fit_transform(df[[ale_col]]).toarray(),columns=[x for i in ohe.categories_ for x in i])
features = df_ohe.columns.tolist()
features.remove("Y")

X_feat_raw = df_ohe.drop(coded_feature.columns.to_list(), axis=1, inplace=False).copy()
X_feat_raw

one_hot_encoder = OneHotEncoder().fit(df[[ale_col]])

def onehot_encode(feat, ohe=one_hot_encoder):
    col_names = ohe.categories_[0]
    feat_coded = pd.DataFrame(ohe.transform(feat).toarray())
    feat_coded.columns = col_names
    return feat_coded

ale_eff = ale(
        X=pd.concat([X_feat_raw,df[ale_col]], axis=1).drop(columns=['Y']),
        model=cat.best_estimator_.named_steps.model,
        feature=[ale_col],
        encode_fun=onehot_encode,
        predictors=features,
)
# Out:
# PyALE._ALE_generic:INFO: categorical feature detected.

# %%
hyeni_pyale(df,df_ohe,cat,'temperature')
# Out:
# PyALE._ALE_generic:INFO: categorical feature detected.
#                      eff  size  lowerCI_95%  upperCI_95%
# temperature
# temperature_80  0.000611  6528          NaN          NaN
# temperature_55  0.004180  3840     0.002034     0.006326
# temperature_30 -0.008653  2316    -0.012171    -0.005136

# %%
import matplotlib as mpl
mpl.style.use('default')

# %%
col_list = list(df.columns) # features to do ALEPlot
col_list.remove('toCoupon_GEQ5min') # only have one value - ALEPlot wont work
col_list.remove('Y') # label

for col in col_list:
    print(col)
    fig, ax = plt.subplots(figsize=(20, 5))
    hyeni_pyale(df,df_ohe,cat,col,fig=fig,ax=ax)
    plt.show()
# Out:
# PyALE._ALE_generic:INFO: categorical feature detected.
# destination
# PyALE._ALE_generic:INFO: categorical feature detected.
# passanger
# PyALE._ALE_generic:INFO: categorical feature detected.
# weather
# PyALE._ALE_generic:INFO: categorical feature detected.
# temperature
# PyALE._ALE_generic:INFO: categorical feature detected.
# time
# PyALE._ALE_generic:INFO: categorical feature detected.
# coupon
# PyALE._ALE_generic:INFO: categorical feature detected.
# expiration
# PyALE._ALE_generic:INFO: categorical feature detected.
# gender
# PyALE._ALE_generic:INFO: categorical feature detected.
# age
# PyALE._ALE_generic:INFO: categorical feature detected.
# maritalStatus
# PyALE._ALE_generic:INFO: categorical feature detected.
# has_children
# PyALE._ALE_generic:INFO: categorical feature detected.
# education
# PyALE._ALE_generic:INFO: categorical feature detected.
# occupation
# PyALE._ALE_generic:INFO: categorical feature detected.
# income
# PyALE._ALE_generic:INFO: categorical feature detected.
# car
# PyALE._ALE_generic:INFO: categorical feature detected.
# Bar
# PyALE._ALE_generic:INFO: categorical feature detected.
# CoffeeHouse
# PyALE._ALE_generic:INFO: categorical feature detected.
# CarryAway
# PyALE._ALE_generic:INFO: categorical feature detected.
# RestaurantLessThan20
# PyALE._ALE_generic:INFO: categorical feature detected.
# Restaurant20To50
# PyALE._ALE_generic:INFO: categorical feature detected.
# toCoupon_GEQ15min
# PyALE._ALE_generic:INFO: categorical feature detected.
# toCoupon_GEQ25min
# PyALE._ALE_generic:INFO: categorical feature detected.
# direction_same
# PyALE._ALE_generic:INFO: categorical feature detected.
# direction_opp
